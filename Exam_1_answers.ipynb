# %% [markdown]
# Problem 2

# %%
ls -lh
# Out:
# total 1.2M
# -rw-rw-r-- 1 osboxes osboxes 2.2K Sep  6 06:50 Exam_1_answers.ipynb
# -rw-rw-r-- 1 osboxes osboxes 1.1K Sep  6 06:34 LICENSE
# -rw-rw-r-- 1 osboxes osboxes 1.2M Sep  6 06:48 Locus_Germplasm_Phenotype_20130122.txt

# %% [markdown]
# The owner  of this file is osboxes an the gorup owner is also osboxes.
# the first column contains 10 fields. 1: Information regarding what kind of file is.
# the rest of the fields are divided into 3 blocks, the first block refers to the user permissions, the second and third blocks refer to group and all, respectively. This file can be read for everybody, but only user and group can write and no one can execute this file.

# %% [markdown]
# Problem 3

# %%
grep -E -i "Locus_name)"  Locus_Germplasm_Phenotype_20130122.txt
# Out:
# Locus_name)	Germplasm_name	phenotype	pubmed_id

# %% [markdown]
# problem 4

# %%
wc -l Locus_Germplasm_Phenotype_20130122.txt
# Out:
# 7216 Locus_Germplasm_Phenotype_20130122.txt

# %% [markdown]
# problem 5

# %%
grep -E -iv "Locus_name)" Locus_Germplasm_Phenotype_20130122.txt > data_only.csv

# %% [markdown]
# I have just remove the header line because i don't know what exactly lines you refer with only data. We introduce de command v because we want all but the header line

# %% [markdown]
# probelm 6

# %%
grep -i "root" Locus_Germplasm_Phenotype_20130122.txt| wc -l
# Out:
# 857

# %% [markdown]
# We pick only the lines with the word root in the phenotype

# %% [markdown]
# Problem 7

# %%
grep -i "root" Locus_Germplasm_Phenotype_20130122.txt| grep -E -io "AT\wg[0-9]{5}\s" > Root-associated-Loci.txt |wc -l Root-associated-Loci.txt
# Out:
# 840 Root-associated-Loci.txt

# %% [markdown]
# now from the output with the lines that include root, we select the AGI Locus code for every line in order to achieve that we use "AT\wg[0-9]{5}\s" and the command -o to don't pick all the line and we use -E because we have to use extended regular expressions.

# %% [markdown]
# problem 8

# %%
grep -i "root" Locus_Germplasm_Phenotype_20130122.txt| grep -E -io "[0-9]{8}" > Root-associated-Publications.txt |wc -l Root-associated-Publications.txt
# Out:
# 709 Root-associated-Publications.txt

# %%
we use the same but now as we wanted to pick only The Pubmed_ID we use grep -E -io with this "[0-9]{8}"

# %% [markdown]
# problem 9

# %%
grep -i "AT[1-5]" Root-associated-Loci.txt
# Out:
# AT1G01550
# AT1G01550
# AT1G01550
# AT1G02970
# AT1G03000
# AT1G03060
# AT1G03060
# AT1G03060
# AT1G03060
# AT1G04020
# AT1G04030
# AT1G04160
# AT1G04160
# AT1G04160
# AT1G04220
# AT1G04250
# AT1G05180
# AT1G05180
# AT1G05180
# AT1G05850
# AT1G05850
# AT1G05850
# AT1G06290
# AT1G06290
# AT1G08030
# AT1G08260
# AT1G08370
# AT1G08430
# AT1G08430
# AT1G09100
# AT1G09110
# AT1G09940
# AT1G10130
# AT1G10570
# AT1G11130
# AT1G12240
# AT1G12610
# AT1G13290
# AT1G14290
# AT1G14660
# AT1G14660
# AT1G15550
# AT1G15550
# AT1G15690
# AT1G16150
# AT1G17110
# AT1G17170
# AT1G17440
# AT1G17580
# AT1G17580
# AT1G18350
# AT1G18800
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G20700
# AT1G21270
# AT1G21700
# AT1G21970
# AT1G21970
# AT1G22920
# AT1G22920
# AT1G23010
# AT1G23010
# AT1G23310
# AT1G23320
# AT1G23320
# AT1G26870
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27320
# ...

# %% [markdown]
# The genes related to root are in all the chromosomes
